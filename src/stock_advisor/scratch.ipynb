# %%
## pip install finance-datareader
## pip install beautifulsoup4 
## pip install plotly
## pip install matplotlib

from crawler import Crawler

# %%
crawler_samsung = Crawler('005930')
# Out:
# Crawler instance created for stock symbol: 005930

# %%
samsung_data = crawler_samsung.get_stock_data('2023-01-01', '2023-05-01')

# %%
crawler_samsung.get_data_for_date('2023-04-28')
# Out:
# Data for 005930 on 2023-04-28:
# Open: 65200
# High: 65900
# Low: 65000
# Close: 65500
# Volume: 19699481
# Open      6.520000e+04
# High      6.590000e+04
# Low       6.500000e+04
# Close     6.550000e+04
# Volume    1.969948e+07
# Change    1.393189e-02
# Name: 2023-04-28 00:00:00, dtype: float64

# %%
crawler_samsung.plot_stock_data('2023-01-01', '2023-05-01')

# %%
crawler_samsung.calculate_return('2023-01-01', '2023-05-01')
# Out:
# The return rate from 2023-01-01 to 2023-05-01 is 18.02%
# 18.01801801801802

# %%
crawler_samsung.list_stocks('KRX')
# Out:
#         Code        ISU_CD      Name Market   Dept   Close ChangeCode  \
# 0     005930  KR7005930003      삼성전자  KOSPI          77500          1
# 1     000660  KR7000660001    SK하이닉스  KOSPI         174200          2
# 2     373220  KR7373220003  LG에너지솔루션  KOSPI         389000          1
# 3     207940  KR7207940008  삼성바이오로직스  KOSPI         781000          1
# 4     005935  KR7005931001     삼성전자우  KOSPI          65200          1
# ...      ...           ...       ...    ...    ...     ...        ...
# 2798  413300  KR7413300005   티엘엔지니어링  KONEX  일반기업부    2020          2
# 2799  217320  KR7217320001       썬테크  KONEX  일반기업부    2400          2
# 2800  245450  KR7245450002    씨앤에스링크  KONEX  일반기업부    1499          3
# 2801  030790  KR7030790000     비케이탑스  KOSPI             76          2
# 2802  308700  KR7308700004       테크엔  KONEX  일반기업부     199          0
#
#       Changes  ChagesRatio    Open    High     Low    Volume         Amount  \
# ...

# %%
crawler_samsung.calculate_correlation('000660', '2020-01-01', '2020-12-31')  # SK하이닉스와의 상관계수
# Out:
# Crawler instance created for stock symbol: 000660
# 0.7769778586545224
